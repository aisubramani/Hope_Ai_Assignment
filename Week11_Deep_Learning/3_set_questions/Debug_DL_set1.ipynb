# %% [markdown]
# # Debug DL Set2

# %% [markdown]
# **1. ANN Program**

# %%
import numpy as np
from tensorflow import keras
from tensorflow.keras import layers

# Create sample data
X_train = np.random.rand(100, 28, 28, 1).astype("float32")
y_train = np.random.randint(0, 10, size=(100,))

# Build a simple CNN
model = keras.Sequential([                      # FIX: 'Sequential'
    layers.Conv2D(32, (3, 3), activation='relu', # FIX: 'activation'
                  input_shape=(28, 28, 1)),
    layers.MaxPooling2D((2, 2)),
    layers.Flatten(),
    layers.Dense(64, activation='relu'),
    layers.Dense(10, activation='softmax')
])

# Compile the model
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# Train the model
model.fit(X_train, y_train, epochs=5, batch_size=32)
# Out:
# C:\Anaconda3\envs\ssai\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/5
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.1300 - loss: 2.3733
# Epoch 2/5
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.1900 - loss: 2.2627
# Epoch 3/5
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.1900 - loss: 2.2182
# Epoch 4/5
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.1900 - loss: 2.1953
# Epoch 5/5
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.1900 - loss: 2.1472

# %% [markdown]
# **bold text**## 2. CNN Program**

# %% [markdown]
# ## **3.Library Installation Error (ANN)**

# %%
import tensorflow as tf  # Error: Misspelled 'TensorFlow'
from tensorflow import keras
from tensorflow.keras import layers # Error: Misspelled 'Keras'

print("TensorFlow Version:", tf.__version__)
# Out:
# TensorFlow Version: 2.20.0

# %% [markdown]
# ## **4.4. ModuleNotFoundError (Using Pretrained Model)**

# %%
from tensorflow.keras.applications import VGG16 # Error: VGG1 doesn't exist
model = VGG16(weights='imagenet')
# Out:
# ...
# 553467096/553467096 ━━━━━━━━━━━━━━━━━━━━ 114s 0us/step

# %% [markdown]
# ## **5.TypeError (ANN)**

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers

# Create sample data
X_train = np.random.rand(100, 20).astype("float32")
y_train = np.random.randint(0, 2, size=(100,))

# Build model
model = tf.keras.Sequential([
    layers.Dense(32, activation='relu', input_shape=(20,)),
    layers.Dense(1, activation='sigmoid')
])

# Compile
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# Train (FIX: batch_size must be integer)
model.fit(X_train, y_train, epochs=5, batch_size=32)
# Out:
# Epoch 1/5
# C:\Anaconda3\envs\ssai\Lib\site-packages\keras\src\layers\core\dense.py:95: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5800 - loss: 0.7116
# Epoch 2/5
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5700 - loss: 0.7049
# Epoch 3/5
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5700 - loss: 0.7018
# Epoch 4/5
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5700 - loss: 0.7006
# Epoch 5/5
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5700 - loss: 0.6971

# %% [markdown]
# ## **6.ValueError (Pretrained Model)**

# %%
from tensorflow.keras.applications import ResNet50
import numpy as np

# Correct input shape: (1, 224, 224, 3)
input_data = np.random.rand(1, 224, 224, 3).astype("float32")

model = ResNet50(weights='imagenet')

prediction = model.predict(input_data)
print("Prediction shape:", prediction.shape)
# Out:
# ...
# 102967424/102967424 ━━━━━━━━━━━━━━━━━━━━ 22s 0us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Prediction shape: (1, 1000)

# %% [markdown]
# ## **7.ImportError - Missing Library (ANN)**

# %%
import tensorflow as tf                     # FIXED SPELLING
from tensorflow.keras import layers

model = tf.keras.Sequential([
    layers.Dense(32, activation='relu', input_shape=(10,)),   # FIXED
    layers.Dense(1, activation='sigmoid')                     # FIXED
])

print("Model created successfully.")
# Out:
# Model created successfully.

# %% [markdown]
# ## **8. Attribute Error**

# %%
import numpy as np
from tensorflow import keras
from tensorflow.keras import layers

# Correct input shape: (1, 28, 28, 1)
input_data = np.random.rand(1, 28, 28, 1).astype("float32")

model = keras.Sequential([
    layers.Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)),
    layers.MaxPooling2D((2, 2)),      # FIXED
    layers.Flatten(),                 # FIXED
    layers.Dense(10, activation='softmax')
])

# Now prediction works
prediction = model.predict(input_data)
print("Prediction shape:", prediction.shape)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# Prediction shape: (1, 10)

# %% [markdown]
# ## **9.TypeError - Incorrect Loss Function (ANN)**

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers

# Create sample data
X_train = np.random.rand(100, 10).astype("float32")
y_train = np.random.randint(0, 2, size=(100,))

# Build model
model = tf.keras.Sequential([
    layers.Dense(32, activation='relu', input_shape=(10,)),
    layers.Dense(1, activation='sigmoid')
])

# FIX: Loss must be a string or a callable
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',            # FIXED
    metrics=['accuracy']
)

model.fit(X_train, y_train, epochs=5)
# Out:
# Epoch 1/5
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5200 - loss: 0.6935
# Epoch 2/5
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5200 - loss: 0.6910
# Epoch 3/5
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5400 - loss: 0.6893
# Epoch 4/5
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5400 - loss: 0.6877
# Epoch 5/5
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5500 - loss: 0.6873

# %% [markdown]
# ## **10.Invalid Function Error**

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers

# Generate random training data
X_train = np.random.rand(100, 10).astype("float32")
y_train = np.random.randint(0, 2, size=(100,))

# Build model
model = tf.keras.Sequential([
    layers.Dense(32, activation='relu', input_shape=(10,)),
    layers.Dense(1, activation='sigmoid')
])

# FIXED: Correct optimizer and loss
model.compile(
    optimizer='adam',                     # FIXED
    loss='binary_crossentropy',           # FIXED
    metrics=['accuracy']
)

# Train model
model.fit(X_train, y_train, epochs=5)
# Out:
# Epoch 1/5
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.4100 - loss: 0.7486
# Epoch 2/5
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4200 - loss: 0.7339
# Epoch 3/5
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4400 - loss: 0.7237
# Epoch 4/5
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4200 - loss: 0.7132
# Epoch 5/5
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4400 - loss: 0.7059
