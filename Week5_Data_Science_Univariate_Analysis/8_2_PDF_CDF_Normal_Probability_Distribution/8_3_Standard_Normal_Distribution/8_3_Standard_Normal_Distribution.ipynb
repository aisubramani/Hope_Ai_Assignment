# %% [markdown]
# # Class function for Simple Impute,

# %%
#from my_class_univariate import myunivariate
import pandas as pd
import numpy as np
from my_class_univariate import myunivariate
dataset = pd.read_csv("placement_imputed.csv")

#split cat_cals, num_cals
cat_cals, num_cals= myunivariate.df_cat_num_split(dataset)
print(num_cals)
# Out:
# ['sl_no', 'ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary']

# %%
dataset.isnull().sum()
# Out:
# sl_no             0
# gender            0
# ssc_p             0
# ssc_b             0
# hsc_p             0
# hsc_b             0
# hsc_s             0
# degree_p          0
# degree_t          0
# workex            0
# etest_p           0
# specialisation    0
# mba_p             0
# status            0
# salary            0
# dtype: int64

# %%
import seaborn as sns
sns.distplot(dataset['ssc_p'])
# Out:
# C:\Users\15016\AppData\Local\Temp\ipykernel_47436\2003394491.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataset['ssc_p'])
# <Axes: xlabel='ssc_p', ylabel='Density'>

# %%
sns.histplot(
    dataset['ssc_p'], kde=True,
    stat="density", kde_kws=dict(cut=3)
)
# Out:
# <Axes: xlabel='ssc_p', ylabel='Density'>

# %%
def get_pdf_probability(df, startrange, endrange):
    import matplotlib.pyplot as plt
    import seaborn as sns
    from scipy.stats import norm

    # Plot histogram + KDE
    ax = sns.distplot(df,kde=True,kde_kws={'color':'blue'},color='green')
    plt.axvline(startrange, color='red')
    plt.axvline(endrange, color='red')

    # Calculate parameters
    sample_mean = df.mean()
    sample_std = df.std()
    print(f"Mean={sample_mean:.3f}, Standard Deviation={sample_std:.3f}")

    # Define normal distribution with estimated mean & std
    dist = norm(loc=sample_mean, scale=sample_std)

    # Probability between range using CDF
    prob = dist.cdf(endrange) - dist.cdf(startrange)
    print(f"The probability between range({startrange},{endrange}): {(prob*100):.2f} %")

    plt.show()
    return prob

get_pdf_probability(dataset['ssc_p'], 40, 50)
# Out:
# Mean=67.303, Standard Deviation=10.827
# The probability between range(40,50): 4.92 %
# C:\Users\15016\AppData\Local\Temp\ipykernel_47436\977107793.py:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(df,kde=True,kde_kws={'color':'blue'},color='green')
# np.float64(0.04916705533695259)

# %%
#normal For loop
mylist=[]
for val in range(1,10):
    mylist.append(val)
mylist
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
#one liner for loop
mylist1=[val for val in range(1,10)]
mylist1
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
# Hand on CDF
from statsmodels.distributions.empirical_distribution import ECDF
ecdf=ECDF(dataset["ssc_p"])
print(f"{ecdf(60):.2f} %")
# Out:
# 0.24 %

# %%
#Standard Normal distribution
def stdNDgraph(df):
    import seaborn as sns
    my_mean=df.mean()
    my_std=df.std()
    values=[i for i in df]
    z_score=[((j-my_mean)/my_std) for j in values]
    sns.distplot(z_score, kde=True)
    print(sum(z_score)/len(z_score))

stdNDgraph(dataset["ssc_p"])

#for col in dataset:
#    print(cal)
    #import seaborn as sns
    #my_mean=df[cal].mean()
    #my_std=df[cal].std()
    #values=[i for i in df[cal]]
    #z_score=[((j-my_mean)/my_std) for j in values]
# Out:
# -4.2911410858767677e-16
# C:\Users\15016\AppData\Local\Temp\ipykernel_47436\1838556957.py:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(z_score, kde=True)
