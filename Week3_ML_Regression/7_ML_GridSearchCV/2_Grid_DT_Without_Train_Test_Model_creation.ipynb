# %%
#data collection
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

dataset=pd.read_csv("insurance_pre.csv")

#preprocessing
dataset=pd.get_dummies(dataset,drop_first=True).astype(int)

#split input & out put
independent=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]
dependent=dataset['charges']

#grid Model creation 
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor
param_grid = {
    'criterion': ['squared_error', 'absolute_error', 'friedman_mse'],  
    'max_features': [None, 'sqrt', 'log2'],                            
    'splitter': ['best', 'random']
}

grid = GridSearchCV(DecisionTreeRegressor(), param_grid, refit = True, verbose = 3,n_jobs=-1) 
# fitting the model for grid search 
grid.fit(independent, dependent)
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# GridSearchCV(estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'absolute_error',
#                                        'friedman_mse'],
#                          'max_features': [None, 'sqrt', 'log2'],
#                          'splitter': ['best', 'random']},
#              verbose=3)

# %%
# print best parameter after tuning 
#print(grid.best_params_) 
re=grid.cv_results_
print("The R_score value for best parameter {}:".format(grid.best_params_))
print("Best CV Score:", grid.best_score_)
# Out:
# The R_score value for best parameter {'criterion': 'absolute_error', 'max_features': None, 'splitter': 'best'}:
# Best CV Score: 0.7144137838305749

# %%
table=pd.DataFrame.from_dict(re)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.011161      0.001976         0.003456        0.000473
# 1        0.010985      0.002536         0.004045        0.000854
# 2        0.006486      0.000689         0.003233        0.000609
# 3        0.007193      0.000910         0.004808        0.000989
# 4        0.009191      0.002124         0.004702        0.000872
# 5        0.007636      0.001426         0.005142        0.001331
# 6        0.036349      0.003207         0.004058        0.000905
# 7        0.032883      0.003420         0.005362        0.001276
# 8        0.023527      0.002026         0.004610        0.000776
# 9        0.024482      0.003304         0.004045        0.000918
# 10       0.025235      0.002482         0.003874        0.000969
# 11       0.018120      0.000984         0.002866        0.000389
# 12       0.007754      0.000641         0.002921        0.000297
# 13       0.006323      0.000421         0.003599        0.000868
# 14       0.006468      0.000568         0.003157        0.000514
# 15       0.006256      0.001393         0.003293        0.000513
# 16       0.006732      0.000646         0.003582        0.000796
# 17       0.006302      0.000587         0.002986        0.000431
#
#    param_criterion param_max_features param_splitter  \
# 0    squared_error               None           best
# 1    squared_error               None         random
# 2    squared_error               sqrt           best
# 3    squared_error               sqrt         random
# 4    squared_error               log2           best
# 5    squared_error               log2         random
# 6   absolute_error               None           best
# 7   absolute_error               None         random
# 8   absolute_error               sqrt           best
# 9   absolute_error               sqrt         random
# 10  absolute_error               log2           best
# 11  absolute_error               log2         random
# 12    friedman_mse               None           best
# 13    friedman_mse               None         random
# 14    friedman_mse               sqrt           best
# 15    friedman_mse               sqrt         random
# 16    friedman_mse               log2           best
# 17    friedman_mse               log2         random
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.739173
# 1   {'criterion': 'squared_error', 'max_features':...           0.706904
# 2   {'criterion': 'squared_error', 'max_features':...           0.670370
# 3   {'criterion': 'squared_error', 'max_features':...           0.586830
# 4   {'criterion': 'squared_error', 'max_features':...           0.740287
# 5   {'criterion': 'squared_error', 'max_features':...           0.639459
# 6   {'criterion': 'absolute_error', 'max_features'...           0.697228
# 7   {'criterion': 'absolute_error', 'max_features'...           0.689861
# 8   {'criterion': 'absolute_error', 'max_features'...           0.719960
# 9   {'criterion': 'absolute_error', 'max_features'...           0.754623
# 10  {'criterion': 'absolute_error', 'max_features'...           0.714657
# 11  {'criterion': 'absolute_error', 'max_features'...           0.575338
# 12  {'criterion': 'friedman_mse', 'max_features': ...           0.764616
# 13  {'criterion': 'friedman_mse', 'max_features': ...           0.682793
# 14  {'criterion': 'friedman_mse', 'max_features': ...           0.645591
# 15  {'criterion': 'friedman_mse', 'max_features': ...           0.629664
# 16  {'criterion': 'friedman_mse', 'max_features': ...           0.725342
# 17  {'criterion': 'friedman_mse', 'max_features': ...           0.617277
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.679373           0.735534           0.706792
# 1            0.631022           0.754240           0.723254
# 2            0.692943           0.693656           0.635989
# 3            0.659462           0.656444           0.703015
# 4            0.604154           0.732104           0.732491
# 5            0.526156           0.566357           0.624657
# 6            0.690135           0.739544           0.721387
# 7            0.594452           0.758962           0.736250
# 8            0.626854           0.622503           0.726598
# 9            0.633885           0.680004           0.681552
# 10           0.592617           0.722642           0.640019
# 11           0.385022           0.625628           0.612478
# 12           0.665728           0.742136           0.701950
# 13           0.634551           0.725242           0.729270
# 14           0.665483           0.645137           0.729666
# 15           0.645132           0.629475           0.705637
# 16           0.646539           0.709916           0.665872
# 17           0.604672           0.689496           0.666667
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.692197         0.710614        0.023522                3
# 1            0.714481         0.705980        0.040790                5
# 2            0.666773         0.671946        0.021139               12
# 3            0.607607         0.642672        0.041136               16
# 4            0.737807         0.709369        0.052700                4
# 5            0.638878         0.599102        0.045293               17
# 6            0.723775         0.714414        0.018180                1
# 7            0.740548         0.704015        0.059325                6
# 8            0.670626         0.673308        0.044187               11
# 9            0.693420         0.688697        0.038729                9
# 10           0.671893         0.668365        0.048255               13
# 11           0.691742         0.578042        0.103578               18
# 12           0.686848         0.712256        0.036197                2
# 13           0.709887         0.696349        0.034942                7
# 14           0.709602         0.679096        0.034494               10
# 15           0.663149         0.654611        0.028357               15
# 16           0.731753         0.695884        0.033725                8
# 17           0.696465         0.654915        0.037420               14

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or Female 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or No 1:"))
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])# change the paramter,play with it.
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Age: 24
# BMI: 33
# Children: 2
# Sex Male 0 or Female 1: 1
# Smoker Yes 0 or No 1: 0
# Future_Prediction=[3591.]
# C:\Anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(

# %%
#save model
import pickle
filename="final_SAV_grid_DT_Model.sav"
pickle.dump(grid,open(filename,'wb'))
